# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw_data/pads-parkinsons-disease-smartwatch-dataset-1.0.0/preprocessed/file_list.csv')
df.head()
# Out:
#   resource_type  id study_id                 condition  \
# 0       patient   1     PADS                   Healthy
# 1       patient   2     PADS  Other Movement Disorders
# 2       patient   3     PADS                   Healthy
# 3       patient   4     PADS               Parkinson's
# 4       patient   5     PADS               Parkinson's
#
#                                      disease_comment  age_at_diagnosis  age  \
# 0                                                  -                56   56
# 1  Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                  -                45   45
# 3                            IPS akinetic-rigid type                63   67
# 4                            IPS tremordominant type                65   75
#
#    height  weight  gender handedness  appearance_in_kinship  \
# 0     173      78    male      right                   True
# ...

# %%
df.shape
# Out:
# (469, 15)

# %%
df.columns
# Out:
# Index(['resource_type', 'id', 'study_id', 'condition', 'disease_comment',
#        'age_at_diagnosis', 'age', 'height', 'weight', 'gender', 'handedness',
#        'appearance_in_kinship', 'appearance_in_first_grade_kinship',
#        'effect_of_alcohol_on_tremor', 'label'],
#       dtype='object')

# %%
df.dtypes
# Out:
# resource_type                        object
# id                                    int64
# study_id                             object
# condition                            object
# disease_comment                      object
# age_at_diagnosis                      int64
# age                                   int64
# height                                int64
# weight                                int64
# gender                               object
# handedness                           object
# appearance_in_kinship                  bool
# appearance_in_first_grade_kinship    object
# effect_of_alcohol_on_tremor          object
# label                                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# resource_type                          0
# id                                     0
# study_id                               0
# condition                              0
# disease_comment                        0
# age_at_diagnosis                       0
# age                                    0
# height                                 0
# weight                                 0
# gender                                 0
# handedness                             0
# appearance_in_kinship                  0
# appearance_in_first_grade_kinship    288
# effect_of_alcohol_on_tremor            0
# label                                  0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        resource_type          id study_id    condition disease_comment  \
# count            469  469.000000      469          469             469
# unique             1         NaN        1            6             140
# top          patient         NaN     PADS  Parkinson's               -
# freq             469         NaN      469          276              94
# mean             NaN  235.000000      NaN          NaN             NaN
# std              NaN  135.532899      NaN          NaN             NaN
# min              NaN    1.000000      NaN          NaN             NaN
# 25%              NaN  118.000000      NaN          NaN             NaN
# 50%              NaN  235.000000      NaN          NaN             NaN
# 75%              NaN  352.000000      NaN          NaN             NaN
# max              NaN  469.000000      NaN          NaN             NaN
#
#         age_at_diagnosis         age      height      weight gender  \
# ...

# %%
sns.histplot(df['label']);
