# %% [markdown]
# # Plotting

# %% [markdown]
# Plotting different average time series

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from spark.utils import get_channel_names
import spark.params as params

# %%
raw_data_prep_dir = '../raw_data/pads-parkinsons-disease-smartwatch-dataset-1.0.0/preprocessed/'

# %%
file_list = pd.read_csv(raw_data_prep_dir  + "file_list.csv")
file_list
# Out:
#     resource_type   id study_id                 condition  \
# 0         patient    1     PADS                   Healthy
# 1         patient    2     PADS  Other Movement Disorders
# 2         patient    3     PADS                   Healthy
# 3         patient    4     PADS               Parkinson's
# 4         patient    5     PADS               Parkinson's
# ..            ...  ...      ...                       ...
# 464       patient  465     PADS               Parkinson's
# 465       patient  466     PADS                   Healthy
# 466       patient  467     PADS               Parkinson's
# 467       patient  468     PADS               Parkinson's
# 468       patient  469     PADS               Parkinson's
#
#                                        disease_comment  age_at_diagnosis  age  \
# 0                                                    -                56   56
# 1    Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                    -                45   45
# 3                              IPS akinetic-rigid type                63   67
# 4                              IPS tremordominant type                65   75
# ..                                                 ...               ...  ...
# 464                                     IPS mixed type                62   65
# 465                                                  -                84   84
# 466  Essential Tremor, starting IPS tremordominant ...                55   57
# 467                                     IPS mixed type                73   76
# 468                            IPS tremordominant type                44   54
#
#      height  weight  gender handedness  appearance_in_kinship  \
# 0       173      78    male      right                   True
# 1       193     104    male      right                  False
# 2       170      78  female      right                  False
# 3       161      90  female      right                  False
# 4       172      86    male       left                  False
# ..      ...     ...     ...        ...                    ...
# 464     175      80    male      right                   True
# 465     172      74  female      right                   True
# 466     190     100    male      right                  False
# 467     198     118    male      right                  False
# 468     165      67  female      right                  False
#
#     appearance_in_first_grade_kinship effect_of_alcohol_on_tremor  label
# 0                                True                     Unknown      0
# 1                                 NaN                   No effect      2
# 2                                 NaN                     Unknown      0
# 3                                 NaN                   No effect      1
# 4                                 NaN                     Unknown      1
# ..                                ...                         ...    ...
# 464                             False                   No effect      1
# 465                              True                   No effect      0
# 466                               NaN                 Improvement      1
# 467                               NaN                   No effect      1
# 468                               NaN                     Unknown      1
#
# [469 rows x 15 columns]

# %%
time_data = []
y = []
X_to_split = []
for idx, subject_idx in enumerate(file_list['id']):
    file_name = raw_data_prep_dir + f'movement/{subject_idx:03d}_ml.bin'
    time_idx_data = np.fromfile(file_name, dtype=np.float32).reshape((-1, 976))
    time_data.append(time_idx_data)
    y_idx = file_list[file_list['id']==subject_idx].label.values
    X_id = idx
    y.append(y_idx)
    X_to_split.append(X_id)

X_to_split = np.array(X_to_split)
y = np.array(y).flatten()
time_data = np.array(time_data)
print(time_data.shape)
time_data.shape[0]
range(time_data.shape[0])
# Out:
# (469, 132, 976)
# range(0, 469)

# %%
channels = get_channel_names()
channels[93]
# Out:
# 'CrossArms_Rotation_RightWrist_X'

# %%
col = ['b','r','y']
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 0
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.015, 0.015)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.015, 0.015)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.015, 0.015)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 66
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.015, 0.015)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.015, 0.015)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.015, 0.015)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 78
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.1, 0.1)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.1, 0.1)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.1, 0.1)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 99
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.5, 0.5)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.5, 0.5)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.5, 0.5)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %% [markdown]
# # TS FRESH selected time series

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 48
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.01, 0.01)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.01, 0.01)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.01, 0.01)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 51
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.2, 0.2)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.2, 0.2)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.2, 0.2)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 54
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.02, 0.02)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.02, 0.02)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.02, 0.02)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')

# %%
fig, ax = plt.subplots(3,3, figsize = (15,15))
chan_pick = 93
for cond in range(len(params.CONDITION_DICT)):
    ax[cond,0].plot(time_data[y==cond,chan_pick,:].mean(axis = 0), col[cond])
    ax[cond,0].set_ylim(-0.5, 0.5)
    ax[cond,0].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,0].set_title(f'{channels[chan_pick]}\n{params.CONDITION_DICT[cond]}')

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,1].plot(time_data[y==cond,chan_pick+1,:].mean(axis = 0), col[cond])
    ax[cond,1].set_ylim(-0.5, 0.5)
    ax[cond,1].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,1].set_title(f'{channels[chan_pick+1]}\n{params.CONDITION_DICT[cond]}')
    plt.suptitle(channels[chan_pick+1])

for cond in range(len(params.CONDITION_DICT)):
    ax[cond,2].plot(time_data[y==cond,chan_pick+2,:].mean(axis = 0), col[cond])
    ax[cond,2].set_ylim(-0.5, 0.5)
    ax[cond,2].set_title(params.CONDITION_DICT[cond])
    if cond ==0:
        ax[cond,2].set_title(f'{channels[chan_pick+2]}\n{params.CONDITION_DICT[cond]}')
