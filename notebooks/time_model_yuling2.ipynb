# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Masking, Input, Normalization

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Model, regularizers, layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix


from sklearn.preprocessing import StandardScaler

# %%
raw_data_prep_dir = '../raw_data/pads-parkinsons-disease-smartwatch-dataset-1.0.0/preprocessed/'

# %%
file_list = pd.read_csv(raw_data_prep_dir  + "file_list.csv")
file_list
# Out:
#     resource_type   id study_id                 condition  \
# 0         patient    1     PADS                   Healthy
# 1         patient    2     PADS  Other Movement Disorders
# 2         patient    3     PADS                   Healthy
# 3         patient    4     PADS               Parkinson's
# 4         patient    5     PADS               Parkinson's
# ..            ...  ...      ...                       ...
# 464       patient  465     PADS               Parkinson's
# 465       patient  466     PADS                   Healthy
# 466       patient  467     PADS               Parkinson's
# 467       patient  468     PADS               Parkinson's
# 468       patient  469     PADS               Parkinson's
#
#                                        disease_comment  age_at_diagnosis  age  \
# 0                                                    -                56   56
# 1    Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                    -                45   45
# 3                              IPS akinetic-rigid type                63   67
# 4                              IPS tremordominant type                65   75
# ..                                                 ...               ...  ...
# 464                                     IPS mixed type                62   65
# 465                                                  -                84   84
# 466  Essential Tremor, starting IPS tremordominant ...                55   57
# 467                                     IPS mixed type                73   76
# 468                            IPS tremordominant type                44   54
#
#      height  weight  gender handedness  appearance_in_kinship  \
# 0       173      78    male      right                   True
# 1       193     104    male      right                  False
# 2       170      78  female      right                  False
# 3       161      90  female      right                  False
# 4       172      86    male       left                  False
# ..      ...     ...     ...        ...                    ...
# 464     175      80    male      right                   True
# 465     172      74  female      right                   True
# 466     190     100    male      right                  False
# 467     198     118    male      right                  False
# 468     165      67  female      right                  False
#
#     appearance_in_first_grade_kinship effect_of_alcohol_on_tremor  label
# 0                                True                     Unknown      0
# 1                                 NaN                   No effect      2
# 2                                 NaN                     Unknown      0
# 3                                 NaN                   No effect      1
# 4                                 NaN                     Unknown      1
# ..                                ...                         ...    ...
# 464                             False                   No effect      1
# 465                              True                   No effect      0
# 466                               NaN                 Improvement      1
# 467                               NaN                   No effect      1
# 468                               NaN                     Unknown      1
#
# [469 rows x 15 columns]

# %%
time_data = []
y = []
X_to_split = []
for idx, subject_idx in enumerate(file_list['id']):
    file_name = raw_data_prep_dir + f'movement/{subject_idx:03d}_ml.bin'
    time_idx_data = np.fromfile(file_name, dtype=np.float32).reshape((-1, 976))
    time_data.append(time_idx_data)
    y_idx = file_list[file_list['id']==subject_idx].label.values
    X_id = idx
    y.append(y_idx)
    X_to_split.append(X_id)

X_to_split = np.array(X_to_split)
y = np.array(y).flatten()
print(X_to_split.shape, y.shape)
# Out:
# (469,) (469,)

# %%
channels = []
for task in ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold", "HoldWeight",
                "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]:
    for device_location in ["LeftWrist", "RightWrist"]:
        for sensor in ["Acceleration", "Rotation"]:
            for axis in ["X", "Y", "Z"]:
                channel = f"{task}_{sensor}_{device_location}_{axis}"
                channels.append(channel)
len(channels)
# Out:
# 132

# %%
X_train_idx, X_test_idx, y_train, y_test = train_test_split(X_to_split, y, test_size=0.20, random_state=42, stratify = y)

# %%
time_data_array = np.array(time_data)
print(time_data_array.shape)
# Out:
# (469, 132, 976)

# %%
X_train = time_data_array[X_train_idx]
X_test = time_data_array[X_test_idx]
print(len(X_train), len(X_test))
print(len(y_train), len(y_test))
# Out:
# 375 94
# 375 94

# %%
n_obs, n_chan, n_time =  X_train.shape
print(n_obs, n_chan, n_time)
X_train_nn = X_train.reshape(n_obs, n_time, n_chan)
X_train_nn.shape

n_obs_test, n_chan_test, n_time_test =  X_test.shape
print(n_obs_test, n_chan_test, n_time_test)
X_test_nn = X_test.reshape(n_obs_test, n_time_test, n_chan_test)
X_train_nn.shape
# Out:
# 375 132 976
# 94 132 976
# (375, 976, 132)

# %%
y_train_cat = to_categorical(y_train)
y_test_cat  = to_categorical(y_test)

# %%
X_test_nn[1:]
# Out:
# array([[[-4.43387637e-03, -9.25870240e-03, -9.99780931e-03, ...,
#           3.03398957e-03, -8.40053253e-04, -1.81826414e-03],
#         [-1.81499508e-03, -1.79384463e-03, -1.79075450e-03, ...,
#           1.28893924e-04,  1.12025905e-03,  1.13437920e-04],
#         [ 1.61023039e-04,  1.18511112e-03,  1.22500723e-03, ...,
#           4.54206392e-03,  2.59471126e-03,  1.65825360e-03],
#         ...,
#         [-1.48406737e-02,  4.42652963e-05,  2.44781021e-02, ...,
#           2.97743306e-02,  4.35587838e-02,  4.14093472e-02],
#         [ 2.54550166e-02,  3.14198760e-03, -1.81039125e-02, ...,
#          -4.55813408e-02,  1.07074287e-02,  6.06156029e-02],
#         [ 9.45774242e-02,  1.03049204e-01,  9.87681076e-02, ...,
#          -6.57974631e-02, -8.49236846e-02, -1.09361649e-01]],
#
#        [[ 9.48457528e-05,  1.32816867e-03, -1.29215710e-03, ...,
#           9.09855822e-04, -1.06748508e-03, -2.21050973e-03],
#         [-1.53201667e-03, -2.81168497e-03, -1.21852895e-03, ...,
#           1.53782507e-02,  1.40629690e-02,  1.08983330e-02],
#         [ 6.80991448e-03,  2.81534414e-03, -2.25458341e-03, ...,
#           1.04651488e-02,  1.02618216e-02,  9.21920128e-03],
#         ...,
#         [-6.36051744e-02, -1.23140678e-01, -1.77350119e-01, ...,
#          -7.97189190e-04, -2.94811651e-02, -4.85949367e-02],
#         [-5.17676920e-02, -6.55530170e-02, -8.35918039e-02, ...,
#          -5.60302846e-02, -2.84049809e-02, -1.56548303e-02],
#         [-1.88042857e-02, -2.72603538e-02, -4.52887565e-02, ...,
#           1.62449107e-02,  8.83007143e-03,  3.43642430e-04]],
#
#        [[ 1.02452962e-02,  1.11337593e-02,  1.10721830e-02, ...,
#           3.82283848e-04,  2.27746880e-03,  2.27800105e-03],
#         [-6.40424958e-04, -6.52648043e-04, -2.58563086e-03, ...,
#           5.41124213e-03,  3.53196333e-03,  3.62553843e-03],
#         [ 2.68670171e-03,  7.76964938e-04, -2.15165387e-03, ...,
#          -1.00734679e-03, -9.35527263e-04, -8.48150929e-04],
#         ...,
#         [ 1.11734226e-01,  1.10688142e-01,  1.21324003e-01, ...,
#          -1.24999829e-01, -1.74926370e-01, -2.25905135e-01],
#         [-2.64128566e-01, -2.64112055e-01, -2.46052414e-01, ...,
#          -3.91476974e-02, -1.68738160e-02, -7.34875537e-03],
#         [-1.16153397e-02, -7.37718446e-03, -2.54477989e-02, ...,
#           2.66594123e-02,  4.36475836e-02,  6.91356361e-02]],
#
#        ...,
#
#        [[ 2.98501514e-02,  2.59926859e-02,  2.00732723e-02, ...,
#          -5.18251327e-04,  2.45432043e-03,  6.28001336e-03],
#         [ 7.17169698e-03,  6.18984364e-03,  1.22946920e-03, ...,
#          -1.53997436e-03, -2.66462751e-03, -8.78949708e-04],
#         [-1.08633202e-03, -1.21441029e-03, -2.65253911e-04, ...,
#          -6.53876108e-04, -7.67932564e-04, -8.30878096e-04],
#         ...,
#         [ 1.00930107e+00,  1.64160740e+00,  1.94517362e+00, ...,
#          -2.76467538e+00, -2.14307404e+00, -6.88233256e-01],
#         [ 5.32348096e-01,  1.28547537e+00,  1.99585032e+00, ...,
#          -3.46595025e+00, -3.36642051e+00, -3.15524864e+00],
#         [-2.81644011e+00, -2.44558668e+00, -2.06156802e+00, ...,
#          -2.34113550e+00, -1.59412909e+00, -4.77185935e-01]],
#
#        [[-1.03185112e-02, -1.06309233e-02, -1.12967389e-02, ...,
#          -3.72981973e-04,  7.37908937e-04,  8.49069795e-04],
#         [ 6.46892760e-04,  9.47656372e-05, -3.33804695e-04, ...,
#          -1.98693108e-03, -1.47827901e-04,  1.72277645e-03],
#         [ 1.71073445e-03,  2.59441976e-03, -1.00281817e-04, ...,
#           6.55587995e-04,  4.30790999e-04, -9.86379018e-05],
#         ...,
#         [ 2.65763141e-02,  2.54388768e-02,  2.12243237e-02, ...,
#          -3.98170240e-02, -3.35667506e-02, -3.09222341e-02],
#         [-2.44422294e-02, -1.49509907e-02,  1.52808544e-03, ...,
#           4.63886186e-04,  2.45207511e-02,  2.62067989e-02],
#         [ 9.06126946e-03, -1.17947441e-02, -3.29017267e-02, ...,
#          -5.26780169e-03, -7.39150681e-03, -1.01113934e-02]],
#
#        [[ 4.62400261e-03,  6.21386850e-03,  5.93274506e-03, ...,
#           5.67443809e-03,  3.81426839e-03,  1.96047616e-03],
#         [ 3.07171745e-03,  3.24764219e-03,  2.45105755e-03, ...,
#          -9.73683957e-04, -9.67691885e-04, -1.95155409e-03],
#         [-3.58305897e-06, -1.96198141e-03, -1.01155357e-03, ...,
#          -5.74746693e-04,  4.19073243e-04,  4.58741968e-04],
#         ...,
#         [-1.56276692e-02, -3.89726721e-02, -6.01886772e-02, ...,
#           6.61570057e-02,  3.21820639e-02,  1.20094176e-02],
#         [ 3.29991803e-04, -7.39001087e-04, -1.81365327e-03, ...,
#          -9.41969082e-02, -7.29712546e-02, -5.38742580e-02],
#         [-4.53914925e-02, -4.22154032e-02, -5.17827421e-02, ...,
#          -7.61731714e-02, -1.01667210e-01, -1.27154469e-01]]],
#       dtype=float32)

# %%
def initialize_model_lstm(input_shape:tuple, dropout_rate: float = 0.3) -> Model:
    model = Sequential()
   
    
    normalizer = Normalization(axis = -1)
    normalizer.adapt(X_train_nn)
    model.add(Input(shape=input_shape))
    model.add(normalizer)
 

    #two lstm layers to better capture
    model.add(LSTM(units=128, activation='tanh',
                   return_sequences=True))
    model.add(LSTM(units=64, activation='tanh'))

    #model.add(layers.Dropout(dropout_rate))

    #dense layer with batch normalization
    # model.add(layers.Dense(32, activation='relu'))
    # model.add(layers.BatchNormalization())
    # model.add(layers.Dropout(dropout_rate))

    # model.add(layers.Dense(16, activation='relu'))
    # model.add(layers.Dropout(dropout_rate))

    # #output layer with 3 classification
    # model.add(layers.Dense(3, activation='softmax'))
    
    
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.2))

    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dropout(0.1))

    model.add(layers.Dense(16, activation='relu'))  # Keep this layer
    model.add(layers.Dropout(0.1))

    model.add(layers.Dense(3, activation='softmax'))

    return model

# %%
model_lstm = initialize_model_lstm(input_shape=X_train_nn.shape[1:])

model_lstm.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=0.005),
    metrics=['accuracy', 'precision', 'recall'])

# %%
model_lstm.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_3 (Normalization) │ (None, 976, 132)       │           265 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 976, 128)       │       133,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 190,380 (743.68 KB)
#  Trainable params: 189,987 (742.14 KB)
#  Non-trainable params: 393 (1.54 KB)

# %%
es = EarlyStopping(
    monitor="val_loss",
    patience=50,
    restore_best_weights=True,
    verbose=0
)

reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=15,
        verbose=1,
        min_lr=0
    )

history = model_lstm.fit(
    X_train_nn,
    y_train_cat,
    validation_split = 0.2,
    epochs=150,
    batch_size = 32,
    callbacks=[es, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.3533 - loss: 1.1952 - precision: 0.4022 - recall: 0.1233 - val_accuracy: 0.6267 - val_loss: 1.0391 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0050
# Epoch 2/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.5567 - loss: 1.0004 - precision: 0.5887 - recall: 0.2767 - val_accuracy: 0.6267 - val_loss: 1.0043 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0050
# Epoch 3/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6033 - loss: 0.9123 - precision: 0.6615 - recall: 0.4233 - val_accuracy: 0.5600 - val_loss: 1.0133 - val_precision: 1.0000 - val_recall: 0.0267 - learning_rate: 0.0050
# Epoch 4/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5633 - loss: 0.9261 - precision: 0.6541 - recall: 0.4033 - val_accuracy: 0.6000 - val_loss: 1.0021 - val_precision: 1.0000 - val_recall: 0.0400 - learning_rate: 0.0050
# Epoch 5/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5900 - loss: 0.9359 - precision: 0.6352 - recall: 0.3367 - val_accuracy: 0.6267 - val_loss: 0.9907 - val_precision: 0.8000 - val_recall: 0.0533 - learning_rate: 0.0050
# Epoch 6/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6233 - loss: 0.8553 - precision: 0.7030 - recall: 0.4733 - val_accuracy: 0.6133 - val_loss: 0.9984 - val_precision: 1.0000 - val_recall: 0.0133 - learning_rate: 0.0050
# Epoch 7/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6200 - loss: 0.8144 - precision: 0.7500 - recall: 0.4700 - val_accuracy: 0.6133 - val_loss: 0.9880 - val_precision: 0.8333 - val_recall: 0.1333 - learning_rate: 0.0050
# Epoch 8/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.6567 - loss: 0.7515 - precision: 0.7606 - recall: 0.5400 - val_accuracy: 0.6400 - val_loss: 0.9203 - val_precision: 0.6271 - val_recall: 0.4933 - learning_rate: 0.0050
# Epoch 9/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.6900 - loss: 0.7108 - precision: 0.7647 - recall: 0.5633 - val_accuracy: 0.4933 - val_loss: 1.0303 - val_precision: 0.7000 - val_recall: 0.0933 - learning_rate: 0.0050
# Epoch 10/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7000 - loss: 0.7185 - precision: 0.7660 - recall: 0.6000 - val_accuracy: 0.5733 - val_loss: 1.0622 - val_precision: 0.5962 - val_recall: 0.4133 - learning_rate: 0.0050
# Epoch 11/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7167 - loss: 0.6489 - precision: 0.7692 - recall: 0.6333 - val_accuracy: 0.5067 - val_loss: 1.0700 - val_precision: 0.5909 - val_recall: 0.3467 - learning_rate: 0.0050
# Epoch 12/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7267 - loss: 0.6330 - precision: 0.8162 - recall: 0.6367 - val_accuracy: 0.5467 - val_loss: 1.0277 - val_precision: 0.6415 - val_recall: 0.4533 - learning_rate: 0.0050
# Epoch 13/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7400 - loss: 0.6604 - precision: 0.7579 - recall: 0.6367 - val_accuracy: 0.4533 - val_loss: 1.0086 - val_precision: 0.6970 - val_recall: 0.3067 - learning_rate: 0.0050
# Epoch 14/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7500 - loss: 0.6055 - precision: 0.8361 - recall: 0.6633 - val_accuracy: 0.3867 - val_loss: 1.1336 - val_precision: 0.6053 - val_recall: 0.3067 - learning_rate: 0.0050
# Epoch 15/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7667 - loss: 0.5753 - precision: 0.8272 - recall: 0.6700 - val_accuracy: 0.5200 - val_loss: 0.9674 - val_precision: 0.7111 - val_recall: 0.4267 - learning_rate: 0.0050
# Epoch 16/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7667 - loss: 0.5689 - precision: 0.8228 - recall: 0.6967 - val_accuracy: 0.5733 - val_loss: 0.9985 - val_precision: 0.5714 - val_recall: 0.3733 - learning_rate: 0.0050
# Epoch 17/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8133 - loss: 0.4565 - precision: 0.8550 - recall: 0.7467 - val_accuracy: 0.5067 - val_loss: 1.1792 - val_precision: 0.5965 - val_recall: 0.4533 - learning_rate: 0.0050
# Epoch 18/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8300 - loss: 0.4939 - precision: 0.8593 - recall: 0.7733 - val_accuracy: 0.3733 - val_loss: 1.1295 - val_precision: 0.4314 - val_recall: 0.2933 - learning_rate: 0.0050
# Epoch 19/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8267 - loss: 0.4410 - precision: 0.8614 - recall: 0.7667 - val_accuracy: 0.5067 - val_loss: 1.1479 - val_precision: 0.5593 - val_recall: 0.4400 - learning_rate: 0.0050
# Epoch 20/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8367 - loss: 0.3975 - precision: 0.8906 - recall: 0.7867 - val_accuracy: 0.4267 - val_loss: 1.4021 - val_precision: 0.4697 - val_recall: 0.4133 - learning_rate: 0.0050
# Epoch 21/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9000 - loss: 0.3200 - precision: 0.9225 - recall: 0.8733 - val_accuracy: 0.4800 - val_loss: 1.6909 - val_precision: 0.4795 - val_recall: 0.4667 - learning_rate: 0.0050
# Epoch 22/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8900 - loss: 0.2537 - precision: 0.9138 - recall: 0.8833 - val_accuracy: 0.5200 - val_loss: 2.1290 - val_precision: 0.5200 - val_recall: 0.5200 - learning_rate: 0.0050
# Epoch 23/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 996ms/step - accuracy: 0.8929 - loss: 0.2758 - precision: 0.8938 - recall: 0.8733
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8800 - loss: 0.3567 - precision: 0.8797 - recall: 0.8533 - val_accuracy: 0.5200 - val_loss: 1.6830 - val_precision: 0.5068 - val_recall: 0.4933 - learning_rate: 0.0050
# Epoch 24/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9267 - loss: 0.2500 - precision: 0.9343 - recall: 0.9000 - val_accuracy: 0.4533 - val_loss: 1.7345 - val_precision: 0.4571 - val_recall: 0.4267 - learning_rate: 5.0000e-04
# Epoch 25/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 936ms/step - accuracy: 0.9500 - loss: 0.1622 - precision: 0.9524 - recall: 0.9333 - val_accuracy: 0.4133 - val_loss: 1.8960 - val_precision: 0.4110 - val_recall: 0.4000 - learning_rate: 5.0000e-04
# Epoch 26/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 976ms/step - accuracy: 0.9633 - loss: 0.1241 - precision: 0.9730 - recall: 0.9600 - val_accuracy: 0.4267 - val_loss: 2.0065 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-04
# Epoch 27/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 987ms/step - accuracy: 0.9667 - loss: 0.1174 - precision: 0.9795 - recall: 0.9567 - val_accuracy: 0.4267 - val_loss: 2.1294 - val_precision: 0.4247 - val_recall: 0.4133 - learning_rate: 5.0000e-04
# Epoch 28/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 971ms/step - accuracy: 0.9700 - loss: 0.1043 - precision: 0.9797 - recall: 0.9633 - val_accuracy: 0.4267 - val_loss: 2.2191 - val_precision: 0.4167 - val_recall: 0.4000 - learning_rate: 5.0000e-04
# Epoch 29/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 943ms/step - accuracy: 0.9800 - loss: 0.0868 - precision: 0.9865 - recall: 0.9733 - val_accuracy: 0.4133 - val_loss: 2.2974 - val_precision: 0.4225 - val_recall: 0.4000 - learning_rate: 5.0000e-04
# Epoch 30/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 987ms/step - accuracy: 0.9900 - loss: 0.0701 - precision: 0.9933 - recall: 0.9833 - val_accuracy: 0.4133 - val_loss: 2.3716 - val_precision: 0.4286 - val_recall: 0.4000 - learning_rate: 5.0000e-04
# Epoch 31/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9900 - loss: 0.0705 - precision: 0.9966 - recall: 0.9833 - val_accuracy: 0.4400 - val_loss: 2.4336 - val_precision: 0.4306 - val_recall: 0.4133 - learning_rate: 5.0000e-04
# Epoch 32/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9833 - loss: 0.0773 - precision: 0.9865 - recall: 0.9733 - val_accuracy: 0.4400 - val_loss: 2.4795 - val_precision: 0.4384 - val_recall: 0.4267 - learning_rate: 5.0000e-04
# Epoch 33/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9933 - loss: 0.0487 - precision: 0.9933 - recall: 0.9933 - val_accuracy: 0.4533 - val_loss: 2.5587 - val_precision: 0.4384 - val_recall: 0.4267 - learning_rate: 5.0000e-04
# Epoch 34/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 980ms/step - accuracy: 0.9833 - loss: 0.0677 - precision: 0.9899 - recall: 0.9800 - val_accuracy: 0.4533 - val_loss: 2.6551 - val_precision: 0.4306 - val_recall: 0.4133 - learning_rate: 5.0000e-04
# Epoch 35/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9900 - loss: 0.0486 - precision: 0.9900 - recall: 0.9867 - val_accuracy: 0.4400 - val_loss: 2.7534 - val_precision: 0.4384 - val_recall: 0.4267 - learning_rate: 5.0000e-04
# Epoch 36/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9933 - loss: 0.0492 - precision: 0.9933 - recall: 0.9867 - val_accuracy: 0.4400 - val_loss: 2.8313 - val_precision: 0.4384 - val_recall: 0.4267 - learning_rate: 5.0000e-04
# Epoch 37/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9967 - loss: 0.0467 - precision: 0.9966 - recall: 0.9900 - val_accuracy: 0.4533 - val_loss: 2.9312 - val_precision: 0.4521 - val_recall: 0.4400 - learning_rate: 5.0000e-04
# Epoch 38/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0542 - precision: 0.9935 - recall: 0.9831
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.9999996554106475e-05.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9900 - loss: 0.0516 - precision: 0.9933 - recall: 0.9867 - val_accuracy: 0.4400 - val_loss: 2.9794 - val_precision: 0.4306 - val_recall: 0.4133 - learning_rate: 5.0000e-04
# Epoch 39/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9933 - loss: 0.0401 - precision: 0.9967 - recall: 0.9933 - val_accuracy: 0.4400 - val_loss: 2.9804 - val_precision: 0.4306 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 40/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0236 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.4267 - val_loss: 2.9861 - val_precision: 0.4247 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 41/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 987ms/step - accuracy: 0.9933 - loss: 0.0361 - precision: 0.9933 - recall: 0.9867 - val_accuracy: 0.4267 - val_loss: 2.9871 - val_precision: 0.4306 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 42/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9867 - loss: 0.0492 - precision: 0.9899 - recall: 0.9833 - val_accuracy: 0.4267 - val_loss: 2.9874 - val_precision: 0.4306 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 43/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 994ms/step - accuracy: 0.9900 - loss: 0.0377 - precision: 0.9900 - recall: 0.9867 - val_accuracy: 0.4267 - val_loss: 2.9954 - val_precision: 0.4247 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 44/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0339 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.4267 - val_loss: 3.0050 - val_precision: 0.4247 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 45/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9967 - loss: 0.0325 - precision: 0.9967 - recall: 0.9967 - val_accuracy: 0.4267 - val_loss: 3.0125 - val_precision: 0.4247 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 46/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0359 - precision: 1.0000 - recall: 0.9933 - val_accuracy: 0.4267 - val_loss: 3.0247 - val_precision: 0.4247 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 47/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 997ms/step - accuracy: 0.9933 - loss: 0.0467 - precision: 0.9966 - recall: 0.9900 - val_accuracy: 0.4267 - val_loss: 3.0318 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 48/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9967 - loss: 0.0251 - precision: 1.0000 - recall: 0.9967 - val_accuracy: 0.4267 - val_loss: 3.0373 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 49/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 989ms/step - accuracy: 0.9933 - loss: 0.0372 - precision: 0.9967 - recall: 0.9933 - val_accuracy: 0.4267 - val_loss: 3.0457 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 50/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9967 - loss: 0.0306 - precision: 0.9967 - recall: 0.9967 - val_accuracy: 0.4267 - val_loss: 3.0539 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 51/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9833 - loss: 0.0452 - precision: 0.9899 - recall: 0.9833 - val_accuracy: 0.4267 - val_loss: 3.0589 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 52/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0351 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.4267 - val_loss: 3.0684 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 53/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 896ms/step - accuracy: 0.9854 - loss: 0.0423 - precision: 0.9894 - recall: 0.9809
# Epoch 53: ReduceLROnPlateau reducing learning rate to 4.999999509891496e-06.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 992ms/step - accuracy: 0.9867 - loss: 0.0384 - precision: 0.9933 - recall: 0.9833 - val_accuracy: 0.4267 - val_loss: 3.0749 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-05
# Epoch 54/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 985ms/step - accuracy: 0.9900 - loss: 0.0320 - precision: 0.9933 - recall: 0.9900 - val_accuracy: 0.4267 - val_loss: 3.0700 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-06
# Epoch 55/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9967 - loss: 0.0386 - precision: 0.9966 - recall: 0.9900 - val_accuracy: 0.4267 - val_loss: 3.0681 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-06
# Epoch 56/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9967 - loss: 0.0302 - precision: 1.0000 - recall: 0.9933 - val_accuracy: 0.4267 - val_loss: 3.0712 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-06
# Epoch 57/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0279 - precision: 1.0000 - recall: 0.9967 - val_accuracy: 0.4133 - val_loss: 3.0717 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-06
# Epoch 58/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9900 - loss: 0.0325 - precision: 0.9933 - recall: 0.9900 - val_accuracy: 0.4267 - val_loss: 3.0700 - val_precision: 0.4189 - val_recall: 0.4133 - learning_rate: 5.0000e-06

# %%
model_lstm.evaluate(X_test_nn, y_test_cat)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - accuracy: 0.5745 - loss: 0.9988 - precision: 0.5942 - recall: 0.4362
# [0.9987884163856506,
#  0.5744680762290955,
#  0.5942028760910034,
#  0.43617022037506104]

# %%
model_lstm.save('../spark/lstm_timeseries_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
