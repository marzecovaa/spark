# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path
import json

# %%
basic_info_df = pd.read_csv('./raw_data/pads-parkinsons-disease-smartwatch-dataset-1.0.0/preprocessed/file_list.csv')

# %%
basic_info_df.head(5)
# Out:
#   resource_type  id study_id                 condition  \
# 0       patient   1     PADS                   Healthy
# 1       patient   2     PADS  Other Movement Disorders
# 2       patient   3     PADS                   Healthy
# 3       patient   4     PADS               Parkinson's
# 4       patient   5     PADS               Parkinson's
#
#                                      disease_comment  age_at_diagnosis  age  \
# 0                                                  -                56   56
# 1  Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                  -                45   45
# 3                            IPS akinetic-rigid type                63   67
# 4                            IPS tremordominant type                65   75
#
#    height  weight  gender handedness  appearance_in_kinship  \
# 0     173      78    male      right                   True
# 1     193     104    male      right                  False
# 2     170      78  female      right                  False
# 3     161      90  female      right                  False
# 4     172      86    male       left                  False
#
#   appearance_in_first_grade_kinship effect_of_alcohol_on_tremor  label
# 0                              True                     Unknown      0
# 1                               NaN                   No effect      2
# 2                               NaN                     Unknown      0
# 3                               NaN                   No effect      1
# 4                               NaN                     Unknown      1

# %%
basic_info_df.shape
# Out:
# (469, 15)

# %%
json_files = list(Path('./raw_data/pads-parkinsons-disease-smartwatch-dataset-1.0.0/questionnaire/').glob("*.json"))
print(f"Found {len(json_files)} JSON files")
# Out:
# Found 469 JSON files

# %%
questionnaire_data = []

# %%
for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
            
            subject_id = data.get('subject_id')
            study_id = data.get('study_id')
            questionnaire_name = data.get('questionnaire_name')
            questionnaire_id = data.get('id')
            
            
            row_data = {
                'subject_id': subject_id,
                'study_id': study_id,
                'questionnaire_name': questionnaire_name,
                'questionnaire_id': questionnaire_id
            }
            
           
            items = data.get('item', [])
            for item in items:
                link_id = item.get('link_id')
                answer = item.get('answer')
                
                
                row_data[link_id] = answer
                
            
            questionnaire_data.append(row_data)
            
        except json.JSONDecodeError as e:
            print(f"JSON parsing error in {json_file}: {e}")
        except Exception as e:
            print(f"Error processing {json_file}: {e}")

# %%
questionnaire_data
# Out:
# [{'subject_id': '280',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '146',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '453',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '003',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '392',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '238',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': True,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': True,
#   '23': True,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '111',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '054',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '404',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '384',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': True,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': True},
#  {'subject_id': '107',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '412',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': True,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '042',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '296',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '279',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '150',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '015',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': True,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '445',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '202',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': False,
#   '04': True,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '347',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '081',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '255',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '310',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': True,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': True,
#   '20': True,
#   '21': True,
#   '22': True,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': True},
#  {'subject_id': '469',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '193',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '039',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '243',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': True,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': True},
#  {'subject_id': '306',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': True,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': True,
#   '29': True,
#   '30': True},
#  {'subject_id': '185',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': True,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '214',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '351',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '428',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': True,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': True,
#   '30': True},
#  {'subject_id': '078',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '097',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '326',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '263',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': True,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '408',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '058',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '371',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '234',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': False,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': True,
#   '30': True},
#  {'subject_id': '367',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': True,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': True,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '388',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '222',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '449',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '019',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': True,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '330',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '275',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': True,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': True},
#  {'subject_id': '432',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '062',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '127',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '035',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': True,
#   '07': True,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '465',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '170',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '259',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '189',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '023',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '166',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': True,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': True,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '074',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': True,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '424',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '131',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': True,
#   '15': False,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': True,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '218',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '219',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '075',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': True,
#   '11': True,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '425',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': True},
#  {'subject_id': '130',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': True,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '188',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '022',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': True,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': True,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '167',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '258',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': False,
#   '04': True,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '034',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '464',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': True},
#  {'subject_id': '171',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '433',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': True,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '063',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': True,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': True},
#  {'subject_id': '126',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': True,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': True,
#   '30': False},
#  {'subject_id': '331',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '274',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '448',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '018',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': True,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '366',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '389',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '223',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': True,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '370',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '235',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '409',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': True,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '059',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
# ...
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '145',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': True,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '391',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '057',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': True,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '407',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '112',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '387',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': True,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': True,
#   '22': False,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '368',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': True},
#  {'subject_id': '411',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '041',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '104',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': True,
#   '05': False,
#   '06': True,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '295',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '016',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '446',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '153',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '344',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': True,
#   '07': True,
#   '08': False,
#   '09': False,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': True,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': True,
#   '30': False},
#  {'subject_id': '201',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': False,
#   '10': True,
#   '11': False,
#   '12': True,
#   '13': True,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': True,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '128',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '082',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': True,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': True,
#   '15': True,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '313',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': True,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': True,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': True,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '256',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': True,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '190',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '305',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': False,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': True,
#   '13': False,
#   '14': False,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '240',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': True,
#   '19': False,
#   '20': True,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '169',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': False,
#   '26': True,
#   '27': True,
#   '28': True,
#   '29': False,
#   '30': False},
#  {'subject_id': '186',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': True,
#   '04': True,
#   '05': True,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': True,
#   '15': True,
#   '16': True,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': True,
#   '21': True,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': True,
#   '29': True,
#   '30': True},
#  {'subject_id': '352',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': False,
#   '02': True,
#   '03': True,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': True,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': True,
#   '18': True,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': True,
#   '25': False,
#   '26': True,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '217',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': False,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': False,
#   '14': False,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': False,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': False,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': False,
#   '30': False},
#  {'subject_id': '094',
#   'study_id': 'PADS',
#   'questionnaire_name': 'NMS',
#   'questionnaire_id': 'Non-motor Symptoms',
#   '01': True,
#   '02': False,
#   '03': False,
#   '04': False,
#   '05': False,
#   '06': False,
#   '07': True,
#   '08': True,
#   '09': True,
#   '10': False,
#   '11': False,
#   '12': False,
#   '13': True,
#   '14': True,
#   '15': False,
#   '16': False,
#   '17': False,
#   '18': False,
#   '19': True,
#   '20': False,
#   '21': False,
#   '22': False,
#   '23': True,
#   '24': False,
#   '25': False,
#   '26': False,
#   '27': False,
#   '28': False,
#   '29': False,
#   '30': False}]

# %%
df = pd.DataFrame(questionnaire_data)

# %%
df
# Out:
#     subject_id study_id questionnaire_name    questionnaire_id     01     02  \
# 0          280     PADS                NMS  Non-motor Symptoms  False  False
# 1          146     PADS                NMS  Non-motor Symptoms  False   True
# 2          453     PADS                NMS  Non-motor Symptoms  False  False
# 3          003     PADS                NMS  Non-motor Symptoms  False  False
# 4          392     PADS                NMS  Non-motor Symptoms   True  False
# ..         ...      ...                ...                 ...    ...    ...
# 464        169     PADS                NMS  Non-motor Symptoms  False  False
# 465        186     PADS                NMS  Non-motor Symptoms   True  False
# 466        352     PADS                NMS  Non-motor Symptoms  False   True
# 467        217     PADS                NMS  Non-motor Symptoms   True  False
# 468        094     PADS                NMS  Non-motor Symptoms   True  False
#
#         03     04     05     06  ...     21     22     23     24     25  \
# 0     True  False   True  False  ...  False  False  False   True  False
# 1    False  False  False  False  ...  False  False  False  False  False
# 2    False  False  False  False  ...  False  False  False  False  False
# 3    False  False  False  False  ...  False  False  False  False  False
# 4     True  False  False  False  ...   True  False  False  False  False
# ..     ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 464  False  False   True  False  ...  False   True  False   True  False
# 465   True   True   True  False  ...   True   True  False   True  False
# 466   True  False  False  False  ...  False  False   True   True  False
# 467  False  False  False  False  ...  False  False  False  False  False
# 468  False  False  False  False  ...  False  False   True  False  False
#
#         26     27     28     29     30
# 0    False  False   True  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4     True   True   True  False  False
# ..     ...    ...    ...    ...    ...
# 464   True   True   True  False  False
# 465  False   True   True   True   True
# 466   True   True  False  False  False
# 467  False   True  False  False  False
# 468  False  False  False  False  False
#
# [469 rows x 34 columns]

# %%
basic_info_df.columns.tolist()
# Out:
# ['resource_type',
#  'id',
#  'study_id',
#  'condition',
#  'disease_comment',
#  'age_at_diagnosis',
#  'age',
#  'height',
#  'weight',
#  'gender',
#  'handedness',
#  'appearance_in_kinship',
#  'appearance_in_first_grade_kinship',
#  'effect_of_alcohol_on_tremor',
#  'label']

# %%
df['subject_id'] = df['subject_id'].astype(int)

# %%
df
# Out:
#      subject_id study_id questionnaire_name    questionnaire_id     01     02  \
# 0           280     PADS                NMS  Non-motor Symptoms  False  False
# 1           146     PADS                NMS  Non-motor Symptoms  False   True
# 2           453     PADS                NMS  Non-motor Symptoms  False  False
# 3             3     PADS                NMS  Non-motor Symptoms  False  False
# 4           392     PADS                NMS  Non-motor Symptoms   True  False
# ..          ...      ...                ...                 ...    ...    ...
# 464         169     PADS                NMS  Non-motor Symptoms  False  False
# 465         186     PADS                NMS  Non-motor Symptoms   True  False
# 466         352     PADS                NMS  Non-motor Symptoms  False   True
# 467         217     PADS                NMS  Non-motor Symptoms   True  False
# 468          94     PADS                NMS  Non-motor Symptoms   True  False
#
#         03     04     05     06  ...     21     22     23     24     25  \
# 0     True  False   True  False  ...  False  False  False   True  False
# 1    False  False  False  False  ...  False  False  False  False  False
# 2    False  False  False  False  ...  False  False  False  False  False
# 3    False  False  False  False  ...  False  False  False  False  False
# 4     True  False  False  False  ...   True  False  False  False  False
# ..     ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 464  False  False   True  False  ...  False   True  False   True  False
# 465   True   True   True  False  ...   True   True  False   True  False
# 466   True  False  False  False  ...  False  False   True   True  False
# 467  False  False  False  False  ...  False  False  False  False  False
# 468  False  False  False  False  ...  False  False   True  False  False
#
#         26     27     28     29     30
# 0    False  False   True  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4     True   True   True  False  False
# ..     ...    ...    ...    ...    ...
# 464   True   True   True  False  False
# 465  False   True   True   True   True
# 466   True   True  False  False  False
# 467  False   True  False  False  False
# 468  False  False  False  False  False
#
# [469 rows x 34 columns]

# %%
basic_info_df
# Out:
#     resource_type   id study_id                 condition  \
# 0         patient    1     PADS                   Healthy
# 1         patient    2     PADS  Other Movement Disorders
# 2         patient    3     PADS                   Healthy
# 3         patient    4     PADS               Parkinson's
# 4         patient    5     PADS               Parkinson's
# ..            ...  ...      ...                       ...
# 464       patient  465     PADS               Parkinson's
# 465       patient  466     PADS                   Healthy
# 466       patient  467     PADS               Parkinson's
# 467       patient  468     PADS               Parkinson's
# 468       patient  469     PADS               Parkinson's
#
#                                        disease_comment  age_at_diagnosis  age  \
# 0                                                    -                56   56
# 1    Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                    -                45   45
# 3                              IPS akinetic-rigid type                63   67
# 4                              IPS tremordominant type                65   75
# ..                                                 ...               ...  ...
# 464                                     IPS mixed type                62   65
# 465                                                  -                84   84
# 466  Essential Tremor, starting IPS tremordominant ...                55   57
# 467                                     IPS mixed type                73   76
# 468                            IPS tremordominant type                44   54
#
#      height  weight  gender handedness  appearance_in_kinship  \
# 0       173      78    male      right                   True
# 1       193     104    male      right                  False
# 2       170      78  female      right                  False
# 3       161      90  female      right                  False
# 4       172      86    male       left                  False
# ..      ...     ...     ...        ...                    ...
# 464     175      80    male      right                   True
# 465     172      74  female      right                   True
# 466     190     100    male      right                  False
# 467     198     118    male      right                  False
# 468     165      67  female      right                  False
#
#     appearance_in_first_grade_kinship effect_of_alcohol_on_tremor  label
# 0                                True                     Unknown      0
# 1                                 NaN                   No effect      2
# 2                                 NaN                     Unknown      0
# 3                                 NaN                   No effect      1
# 4                                 NaN                     Unknown      1
# ..                                ...                         ...    ...
# 464                             False                   No effect      1
# 465                              True                   No effect      0
# 466                               NaN                 Improvement      1
# 467                               NaN                   No effect      1
# 468                               NaN                     Unknown      1
#
# [469 rows x 15 columns]

# %%
basic_info_df['id'] = basic_info_df['id'].astype(int)

# %%
merged_df = pd.merge(df, basic_info_df, left_on='subject_id', right_on='id', how='inner')

# %%
basic_info_df.dtypes
# Out:
# resource_type                        object
# id                                    int64
# study_id                             object
# condition                            object
# disease_comment                      object
# age_at_diagnosis                      int64
# age                                   int64
# height                                int64
# weight                                int64
# gender                               object
# handedness                           object
# appearance_in_kinship                  bool
# appearance_in_first_grade_kinship    object
# effect_of_alcohol_on_tremor          object
# label                                 int64
# dtype: object

# %%
df.dtypes
# Out:
# subject_id             int64
# study_id              object
# questionnaire_name    object
# questionnaire_id      object
# 01                      bool
# 02                      bool
# 03                      bool
# 04                      bool
# 05                      bool
# 06                      bool
# 07                      bool
# 08                      bool
# 09                      bool
# 10                      bool
# 11                      bool
# 12                      bool
# 13                      bool
# 14                      bool
# 15                      bool
# 16                      bool
# 17                      bool
# 18                      bool
# 19                      bool
# 20                      bool
# 21                      bool
# 22                      bool
# 23                      bool
# 24                      bool
# 25                      bool
# 26                      bool
# 27                      bool
# 28                      bool
# 29                      bool
# 30                      bool
# dtype: object

# %%
merged_df
# Out:
#      subject_id study_id_x questionnaire_name    questionnaire_id     01  \
# 0           280       PADS                NMS  Non-motor Symptoms  False
# 1           146       PADS                NMS  Non-motor Symptoms  False
# 2           453       PADS                NMS  Non-motor Symptoms  False
# 3             3       PADS                NMS  Non-motor Symptoms  False
# 4           392       PADS                NMS  Non-motor Symptoms   True
# ..          ...        ...                ...                 ...    ...
# 464         169       PADS                NMS  Non-motor Symptoms  False
# 465         186       PADS                NMS  Non-motor Symptoms   True
# 466         352       PADS                NMS  Non-motor Symptoms  False
# 467         217       PADS                NMS  Non-motor Symptoms   True
# 468          94       PADS                NMS  Non-motor Symptoms   True
#
#         02     03     04     05     06  ...  age_at_diagnosis  age  height  \
# 0    False   True  False   True  False  ...                73   77     162
# 1     True  False  False  False  False  ...                68   71     186
# 2    False  False  False  False  False  ...                 0   48     164
# 3    False  False  False  False  False  ...                45   45     170
# 4    False   True  False  False  False  ...                48   55     165
# ..     ...    ...    ...    ...    ...  ...               ...  ...     ...
# 464  False  False  False   True  False  ...                51   56     180
# 465  False   True   True   True  False  ...                60   65     160
# 466   True   True  False  False  False  ...                45   55     172
# 467  False  False  False  False  False  ...                65   73     182
# 468  False  False  False  False  False  ...                67   69     186
#
#      weight  gender  handedness  appearance_in_kinship  \
# 0        65  female       right                  False
# 1        89    male       right                   True
# 2        59  female       right                  False
# 3        78  female       right                  False
# 4        64  female       right                  False
# ..      ...     ...         ...                    ...
# 464      82  female       right                   True
# 465      73  female       right                  False
# 466      80  female       right                   True
# 467      85    male       right                  False
# 468      91    male       right                   True
#
#      appearance_in_first_grade_kinship  effect_of_alcohol_on_tremor  label
# 0                                  NaN                      Unknown      2
# 1                                False                  Improvement      1
# 2                                False                      Unknown      2
# 3                                  NaN                      Unknown      0
# 4                                  NaN                  Improvement      1
# ..                                 ...                          ...    ...
# 464                               True                      Unknown      1
# 465                                NaN                    No effect      1
# 466                              False                    No effect      1
# 467                                NaN                    No effect      1
# 468                               True                    No effect      1
#
# [469 rows x 49 columns]

# %%
merged_df.to_csv('merged_df.csv')
